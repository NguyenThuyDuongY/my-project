# %%
# Mount Drive to Google Colab

# %%
# Read data from insurance_dataset.csv

# %%
# Extract columns Age, BMI, Children to be X = (x1, x2, x3)

# %%
# Extract column Charges to be y

# %%
# Split the dataset (X, y) to (X_train, y_train), (X_test, y_test) with test_size = 0.2

# %%
# Use (X_train, y_train) to create a linear regression model

# %%
# Report the mean_square_error of the model
